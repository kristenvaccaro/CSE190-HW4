# %% [markdown]
# # Designing a Bus Arrival Prediction App
# In this assignment you will design a bus tracking app with failure in mind. You will evaluate how confidence and errors in predictions -- and how they are presented to the user -- affect user experience.

# %% [markdown]
# ## Part 1: Conveying confidence in predictions
#
# ![Screen Shot 2021-10-15 at 4.23.33 PM.png](data:image/png;base64,...)
#
# Many students use the bus for getting around campus. You are building an app to support them.
#
# Your teammate built a model to predict when each bus will arrive. This model uses the current GPS location, but also historical GPS data from all the buses, which can capture things like where buses have typically run into roadwork, construction, traffic, and so on. The model itself produces a likelihood of the bus arriving in one minute intervals from now to 30 minutes in the future.
#
# Your first draft just showed the predicted arrival time (e.g., "3 min"). But your test-users complained, because sometimes the bus arrives early and sometimes it arrives late. Your goal is to convey the confidence along with the arrival time.
#
# If it is helpful, you can (_but are not required_) start from the screencap included at the bottom, that is, imagine it is your first draft app.
#
# ### Task: Create three sketches of an improved bus app. The app should show the predicted arrival time(s) and confidence in some way. You should explain why you chose to show the information that way.

# %% [markdown]
# _Attach a pdf with your sketches. Please include any annotations/description on the pdf itself (not in this notebook)._

# %% [markdown]
# ## Part 2: Managing expectations
#
# The arrival time predictions are bound to inaccurate at least some of the time. You know that people's expectations of a system can greatly affect their perceptions when using it. Beyond your efforts to convey uncertainty, are there other ways you can help manage your users' expectations? Are there ways to fail gracefully? You might also think about things like the difference between when an error means that the bus arrives earlier than you predicted or later than you predicted.
#
# ### Task: Create three sketches of a version of the interface that either manages user expectations, fails gracefully, or both. You should explain why you chose to design things that way.

# %% [markdown]
# _Attach a pdf with your sketches. Please include any annotations/description on the pdf itself (not in this notebook)._

# %% [markdown]
# ## Example Bus App Interface
#
# If you are not a bus rider, you may find it useful to look at this screencap of an existing app that provides bus arrival predictions. This is the "Transit" app. You can (_but are not required_) to imagine this is your first draft app that you will improve on.

# %% [markdown]
# ![bus.png](data:image/png;base64,...)
